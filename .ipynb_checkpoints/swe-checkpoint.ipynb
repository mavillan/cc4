# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.integrate import odeint
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %%
#test u function
def u(x):
    return 2*(1./(1.+np.exp(-x+10)))-1
    #return np.ones(x.shape[0])

def h(x):
    var =  (x-7)*(x-12)*-1
    var /=12
    return var*(np.sign(var)+1)

# %%
x = np.linspace(0, 6*np.pi, 50)
plt.plot(x,u(x))
plt.show()

# %%
plt.plot(x,h(x))
plt.show()

# %%
eps_u = 10.
eps_h = 10.
eps = 10.
N = 100

def phi_u(r, eps_u):
    return np.exp(-eps_u**2 * r**2)

def phi_h(r, eps_h):
    return np.exp(-eps_h**2 * r**2)

# %%
#building the distances matrix
xi = np.linspace(0, 6*np.pi, N)
vi = xi.reshape((N,1))
D = np.abs(vi-xi)

# %%
#finding the initial weights
Gamma_h = np.linalg.solve(phi_h(D, eps), h(xi))
Gamma_u = np.linalg.solve(phi_u(D, eps), u(xi))
print Gamma_h
print Gamma_u
# Out:
# [ -1.80280433e-60   6.77112678e-59  -2.54135365e-57   9.53825759e-56
#   -3.57991725e-54   1.34362145e-52  -5.04290597e-51   1.89271320e-49
#   -7.10376773e-48   2.66619982e-46  -1.00068326e-44   3.75578373e-43
#   -1.40962800e-41   5.29064302e-40  -1.98569435e-38   7.45274637e-37
#   -2.79717915e-35   1.04984268e-33  -3.94028981e-32   1.47887718e-30
#   -5.55055036e-29   2.08324328e-27  -7.81886888e-26   2.93459296e-24
#   -1.10141709e-22   4.13385990e-21  -1.55152828e-19   5.82322588e-18
#   -2.18558438e-16   8.20297747e-15  -3.07875734e-13   1.15552515e-11
#   -4.33693928e-10   1.62774842e-08  -6.10929680e-07   2.29295307e-05
#   -8.60595074e-04   3.22737300e-02   1.77691986e-01   3.08337897e-01
#    4.27599088e-01   5.35385300e-01   6.31698939e-01   7.16539940e-01
#    7.89908305e-01   8.51804033e-01   9.02227126e-01   9.41177582e-01
#    9.68655402e-01   9.84660586e-01   9.89193134e-01   9.82253046e-01
#    9.63840321e-01   9.33954960e-01   8.92596964e-01   8.39766331e-01
#    7.75463061e-01   6.99687156e-01   6.12438615e-01   5.13717435e-01
#    4.03523700e-01   2.81854297e-01   1.48826055e-01   5.40976406e-05
#   -1.51744396e-06   4.04319025e-08  -1.07725929e-09   2.87022740e-11
#   -7.64737460e-13   2.03755070e-14  -5.42880800e-16   1.44644039e-17
#   -3.85386591e-19   1.02681607e-20  -2.73582754e-22   7.28928240e-24
#   -1.94214135e-25   5.17460130e-27  -1.37871008e-28   3.67340668e-30
#   -9.78734889e-32   2.60772103e-33  -6.94795805e-35   1.85119959e-36
#   -4.93229797e-38   1.31415128e-39  -3.50139754e-41   9.32905130e-43
#   -2.48561316e-44   6.62261638e-46  -1.76451623e-47   4.70134061e-49
#   -1.25261548e-50   3.33744282e-52  -8.89221373e-54   2.36922306e-55
#   -6.31250900e-57   1.68189186e-58  -4.48119568e-60   1.19311294e-61]
# [-0.97463366 -0.94862881 -0.94929935 -0.94925447 -0.94922299 -0.94918429
#  -0.94913751 -0.94908091 -0.94901244 -0.94892963 -0.94882945 -0.94870827
#  -0.94856171 -0.94838443 -0.94817002 -0.9479107  -0.94759709 -0.94721784
#  -0.94675925 -0.94620478 -0.94553445 -0.94472417 -0.94374486 -0.94256151
#    9.51997774   9.71037729   9.90077685  10.0911764   10.28157596
#   10.47197551  10.66237507  10.85277462  11.04317418  11.23357373
#   11.42397329  11.61437284  11.8047724   11.99517195  12.1855715
#   12.37597106  12.56637061  12.75677017  12.94716972  13.13756928
#   13.32796883  13.51836839  13.70876794  13.8991675   14.08956705
#   14.27996661  14.47036616  14.66076572  14.85116527  15.04156483
#   15.23196438  15.42236394  15.61276349  15.80316305  15.9935626
#   16.18396215  16.37436171  16.56476126  16.75516082  16.94556037
#   17.13595993  17.32635948  17.51675904  17.70715859  17.89755815
#   18.0879577   18.27835726  18.46875681  18.65915637  18.84955592]

# %%
#approximating function (approximation of u)
def u_app(x, Gamma, Xi, Eps):
    if type(x)==np.ndarray:
        #evaluate multiple points through broadcasting
        n = x.shape[0]
        return np.dot(phi_u(x.reshape((n,1))-Xi, Eps), Gamma)
    else:
        #evaluate a single point
        return np.dot(phi_u(x-Xi, Eps), Gamma)
    
def h_app(x, Gamma, Xi, Eps):
    if type(x)==np.ndarray:
        #evaluate multiple points through broadcasting
        n = x.shape[0]
        return np.dot(phi_h(x.reshape((n,1))-Xi, Eps), Gamma)
    else:
        #evaluate a single point
        return np.dot(phi_h(x-Xi, Eps), Gamma)

# %%
Nx = 100
x = np.linspace(0, 6*np.pi, Nx)
plt.plot(x, h_app(x, Gamma_h, Xi_h, Eps_h))
plt.show()

# %%
plt.plot(x, u_app(x, Gamma_u, Xi_u, Eps_u))
plt.show()

# %% [markdown]
# ### Ecuaciones de evolución a utilizar

# %% [markdown]
# $$ \epsilon_h'(t) = 0 $$
# $$ \gamma_h'(t) = 0 $$
# $$ \xi_h'(t) = \frac{u \gamma _h(t) \epsilon _h(t){}^2+h \gamma _u(t) \epsilon _u(t){}^2}{\gamma _h(t) \epsilon _h(t){}^2}$$
#
# $$ \epsilon_u'(t) = 0 $$
# $$ \gamma_u'(t) = 0 $$
# $$ \xi_u'(t) = \frac{g \gamma _h(t) \epsilon _h(t){}^2+u \gamma _u(t) \epsilon _u(t){}^2}{\gamma _u(t) \epsilon _u(t){}^2} $$

# %%
def dXi(Xi, t):
    m = Xi.shape[0]
    Xi_h = Xi[:m/2]
    Xi_u = Xi[m/2:]
    xi_h_t = (u_app(Xi_u, Gamma_u, Xi_u, Eps_u)*Gamma_h*Eps_h**2 + h_app(Xi_h, Gamma_h, Xi_h, Eps_h)*Gamma_u*Eps_u**2)/(Gamma_h*Eps_h**2)
    xi_u_t = (g*Gamma_h*Eps_h**2 + u_app(Xi_u, Gamma_u, Xi_u, Eps_u)*Gamma_u*Eps_u**2)/(Gamma_u*Eps_u**2)
    return np.concatenate((xi_h_t, xi_u_t))

g = 9.8
Nt = 5000
t = np.linspace(0.,3.,Nt)

sol = odeint(dXi, np.concatenate((Xi_h, Xi_u)), t) #it gives Xi values in time

# %%
print sol.shape
# Out:
# (5000, 200)

# %%
#solution at final time
plt.plot(x, h_app(x, Gamma_h, sol[-1][0:100], Eps_h))
plt.show()

# %%
#solution at final time
plt.plot(x, u_app(x, Gamma_u, sol[-1][100::], Eps_u))
plt.show()

# %%
#generating grids
X, T = np.meshgrid(x, t)

W = np.empty((Nt,Nx))
m = 0
for Xi in sol:
    W[m] = w(x, Gamma, Xi, Eps)
    m +=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-b2403d3b3c2d> in <module>()
#       5 m = 0
#       6 for Xi in sol:
# ----> 7     W[m] = w(x, Gamma, Xi, Eps)
#       8     m +=1
#
# NameError: name 'w' is not defined

# %%
plt.plot(t, sol)
plt.show()

# %%
# %matplotlib inline
m=0
while m<5000:
    plt.plot(x, h_app(x, Gamma_h, sol[m][0:100], Eps_h))
    plt.show()
    m+=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-116-87a0b93bd478> in <module>()
#       2 m=0
#       3 while m<5000:
# ----> 4     plt.plot(x, h_app(x, Gamma_h, sol[m][0:100], Eps_h))
#       5     plt.show()
#       6     m+=1
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3145 @_autogen_docstring(Axes.plot)
#    3146 def plot(*args, **kwargs):
# -> 3147     ax = gca()
#    3148     # allow callers to override the hold state by passing hold=True|False
#    3149     washold = ax.ishold()
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in gca(**kwargs)
#     926     matplotlib.figure.Figure.gca : The figure's gca method.
#     927     """
# --> 928     return gcf().gca(**kwargs)
#     929
#     930 # More ways of creating axes:
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/figure.pyc in gca(self, **kwargs)
#    1331
#    1332         # no axes found, so create one which spans the figure
# -> 1333         return self.add_subplot(1, 1, 1, **kwargs)
#    1334
#    1335     def sca(self, a):
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#    1003                     self._axstack.remove(ax)
#    1004
# -> 1005             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1006
#    1007         self._axstack.add(key, a)
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     518         self._hold = rcParams['axes.hold']
#     519         self._connected = {}  # a dict from events to (id, func)
# --> 520         self.cla()
#     521         # funcs used to format x and y - fall back on major formatters
#     522         self.fmt_xdata = None
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in cla(self)
#     919         self.yaxis.cla()
#     920         for name, spine in six.iteritems(self.spines):
# --> 921             spine.cla()
#     922
#     923         self.ignore_existing_data_limits = True
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/spines.pyc in cla(self)
#     168         self._position = None  # clear position
#     169         if self.axis is not None:
# --> 170             self.axis.cla()
#     171
#     172     def is_frame_like(self):
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in cla(self)
#     740         self._set_artist_props(self.label)
#     741
# --> 742         self.reset_ticks()
#     743
#     744         self.converter = None
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in reset_ticks(self)
#     754         cbook.popall(self.minorTicks)
#     755
# --> 756         self.majorTicks.extend([self._get_tick(major=True)])
#     757         self.minorTicks.extend([self._get_tick(major=False)])
#     758         self._lastNumMajorTicks = 1
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1998         else:
#    1999             tick_kw = self._minor_tick_kw
# -> 2000         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2001
#    2002     def _get_label(self):
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     149
#     150         self.tick1line = self._get_tick1line()
# --> 151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#     153
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick2line(self)
#     551                           markeredgewidth=self._width,
#     552                           zorder=self._zorder)
# --> 553         l.set_transform(self.axes.get_yaxis_transform(which='tick2'))
#     554         self._set_artist_props(l)
#     555         return l
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in get_yaxis_transform(self, which)
#     728         elif which == 'tick2':
#     729             # for cartesian projection, this is top spine
# --> 730             return self.spines['right'].get_spine_transform()
#     731         else:
#     732             raise ValueError('unknown value for which')
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/spines.pyc in get_spine_transform(self)
#     404     def get_spine_transform(self):
#     405         """get the spine transform"""
# --> 406         self._ensure_position_is_set()
#     407         what, how = self._spine_transform
#     408
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/spines.pyc in _ensure_position_is_set(self)
#     150             # default position
#     151             self._position = ('outward', 0.0)  # in points
# --> 152             self.set_position(self._position)
#     153
#     154     def register_axis(self, axis):
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/spines.pyc in set_position(self, position)
#     394
#     395         if self.axis is not None:
# --> 396             self.axis.reset_ticks()
#     397         self.stale = True
#     398
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in reset_ticks(self)
#     754         cbook.popall(self.minorTicks)
#     755
# --> 756         self.majorTicks.extend([self._get_tick(major=True)])
#     757         self.minorTicks.extend([self._get_tick(major=False)])
#     758         self._lastNumMajorTicks = 1
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1998         else:
#    1999             tick_kw = self._minor_tick_kw
# -> 2000         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2001
#    2002     def _get_label(self):
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     154         self.label1 = self._get_text1()
#     155         self.label = self.label1  # legacy name
# --> 156         self.label2 = self._get_text2()
#     157
#     158         self.gridOn = gridOn
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_text2(self)
#     520             color=self._labelcolor,
#     521             verticalalignment=vert,
# --> 522             horizontalalignment=horiz,
#     523             )
#     524         t.set_transform(trans)
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/text.pyc in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     233         self._linespacing = linespacing
#     234         self.set_rotation_mode(rotation_mode)
# --> 235         self.update(kwargs)
#     236
#     237     def update(self, kwargs):
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/text.pyc in update(self, kwargs)
#     240         """
#     241         bbox = kwargs.pop('bbox', None)
# --> 242         super(Text, self).update(kwargs)
#     243         if bbox:
#     244             self.set_bbox(bbox)  # depends on font properties
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in update(self, props)
#     848         changed = False
#     849
# --> 850         for k, v in six.iteritems(props):
#     851             if k in ['axes']:
#     852                 setattr(self, k, v)
#
# /home/martin/anaconda2/lib/python2.7/site-packages/matplotlib/externals/six.pyc in iteritems(d, **kw)
#     574
#     575     def iteritems(d, **kw):
# --> 576         return iter(d.iteritems(**kw))
#     577
#     578     def iterlists(d, **kw):
#
# KeyboardInterrupt:

# %% [markdown]
# #### 3d plot
# fig = plt.figure(figsize=(15,8))
# ax = fig.add_subplot(111, projection='3d')
# ax.plot_surface(X, T, W, antialiased=False, linewidth=0)
# ax.set_xlabel('x')
# ax.set_ylabel('t')
# ax.set_zlabel('w')
# #plt.contour(X, T, W)
# plt.show()
