# %% [markdown]
# # Solving the Shallow Water Equations

# %%
# %matplotlib notebook
import numpy as np
import scipy.integrate as spi
import matplotlib.pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %%
#Initial condition functions
def h0(x):
    var =  (x-8)*(x-12)*-1
    var /=50
    return 10+var*(np.sign(var)+1)

def u0(x):
    #return 2*(1./(1.+np.exp(-x+10)))-1
    return np.zeros(x.shape[0])+0.1

#spatial boundary
a = 0
b = 20

# %%
x = np.linspace(a, b, 100)
plt.xlabel('x')
plt.ylabel('h')
plt.title('Initial condition: h')
plt.plot(x,h0(x))
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.xlabel('x')
plt.ylabel('u')
plt.title('Initial condition: u')
plt.plot(x,u0(x))
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
"""
Kernel functions and his derivatives.
"""
def phi(x, xi, eps):
    return np.exp(-(eps**2)*(x-xi)**2)

def phix(x, xi, eps):
    return -2*(eps**2)*(x-xi)*np.exp(-(eps**2)*(x-xi)**2)

# %%
"""
Setting initial parameters
"""
#Number of kernels/particles to use
N = 150

#shape parameters will be the same for all particles
eps_h = 3.
eps_u = 5.

#collocation points (the same for both)
xi_h = np.linspace(a, b, N, endpoint=True)
xi_u = np.linspace(a, b, N, endpoint=True)

#evaluation points (will be the same as collocations)
x0_h = xi_h.reshape((N,1))
x0_u = xi_u.reshape((N,1))

#sealevel
H = 9.8

#gravity constant
g = 9.8

# %%
#finding the initial weights
Gamma_h = np.linalg.solve(phi(x0_h, xi_h, eps_h), h0(xi_h)-H)
Gamma_u = np.linalg.solve(phi(x0_u, xi_u, eps_u), u0(xi_u))
print('Gamma_h\n',Gamma_h)
print('Gamma_u\n',Gamma_u)
# Out:
# Gamma_h
#  [  5.69962483e-01  -1.17972605e+00   1.93754184e+00  -2.32331471e+00
#    2.66147140e+00  -2.61982738e+00   2.61794723e+00  -2.34690182e+00
#    2.21305568e+00  -1.88260855e+00   1.73775061e+00  -1.42560186e+00
#    1.31487021e+00  -1.04383568e+00   9.75761709e-01  -7.45789951e-01
#    7.15531645e-01  -5.19392396e-01   5.18786615e-01  -3.48221753e-01
#    3.69363700e-01  -2.17031193e-01   2.53208687e-01  -1.13011185e-01
#    1.58681283e-01  -2.55461466e-02   7.60110729e-02   5.44848527e-02
#   -3.47570443e-03   1.35513609e-01  -8.81767998e-02   2.26116518e-01
#   -1.87068247e-01   3.35903172e-01  -3.10645577e-01   4.76532323e-01
#   -4.72040427e-01   6.62959281e-01  -6.88434059e-01   9.15057576e-01
#   -9.82938119e-01   1.25982192e+00  -1.38719973e+00   1.73447907e+00
#   -1.94515552e+00   2.39107054e+00  -2.71869676e+00   3.30354818e+00
#   -3.79666669e+00   4.57928768e+00  -5.30962202e+00   6.37778697e+00
#   -7.45261740e+00   8.93588829e+00  -1.05065974e+01   1.25687693e+01
#   -1.47820992e+01   1.74852059e+01  -2.01915630e+01   2.29862843e+01
#   -2.50605847e+01   2.62999669e+01  -2.61373404e+01   2.51460578e+01
#   -2.31467336e+01   2.09441211e+01  -1.82628495e+01   1.58300858e+01
#   -1.31796285e+01   1.09591761e+01  -8.57620755e+00   6.64907063e+00
        return np.dot(phi(x.reshape((n,1)), Xi, Eps), Gamma)+H
    else:
        #evaluate at single point
        return np.dot(phi(x, Xi, Eps), Gamma)+H

def hx(x, Gamma, Xi, Eps):
    if type(x)==np.ndarray:
        #evaluate at multiple points through broadcasting
        n = x.shape[0]
        return np.dot(phix(x.reshape((n,1)), Xi, Eps), Gamma)
    else:
        #evaluate at a single point 
        return np.dot(phix(x, Xi, Eps), Gamma)

def u(x, Gamma, Xi, Eps):
    if type(x)==np.ndarray:
        #evaluate at multiple points through broadcasting
        n = x.shape[0]
        return np.dot(phi(x.reshape((n,1)), Xi, Eps), Gamma)
    else:
        #evaluate at single point
        return np.dot(phi(x, Xi, Eps), Gamma)

def ux(x, Gamma, Xi, Eps):
    if type(x)==np.ndarray:
        #evaluate at multiple points through broadcasting
        n = x.shape[0]
        return np.dot(phix(x.reshape((n,1)), Xi, Eps), Gamma)
    else:
        #evaluate at a single point 
        return np.dot(phix(x, Xi, Eps), Gamma)

# %% [markdown]
# ### Cutting borders

# %%
#cut = 5
#Gamma_h = Gamma_h[cut:-cut]
#Xi_h = Xi_h[cut:-cut]
#Eps_h = Eps_h[cut:-cut]
#Gamma_u = Gamma_u[cut:-cut]
#Xi_u = Xi_u[cut:-cut]
#Eps_u = Eps_u[cut:-cut]

# %%
x = np.linspace(Xi_h[0], Xi_h[-1], 1000)
plt.plot(x, h(x, Gamma_h, Xi_h, Eps_h))
plt.xlabel('x')
plt.ylabel('h0')
plt.title('Interpolated h0')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.plot(x, hx(x, Gamma_h, Xi_h, Eps_h))
plt.xlabel('x')
plt.ylabel('hx0')
plt.title('Interpolated hx0')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.plot(x, u(x, Gamma_u, Xi_u, Eps_u))
plt.xlabel('x')
plt.ylabel('u0')
plt.title('Interpolated u0')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.plot(x, ux(x, Gamma_u, Xi_u, Eps_u))
plt.xlabel('x')
plt.ylabel('ux0')
plt.title('Interpolated ux0')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Ecuaciones de Evolución

# %% [markdown]
# \begin{align}
# \gamma _h'(t) &= -\left(\frac{H}{N} + \gamma _h(t)\right)u_x  \\
# \xi _h'(t) &= u \\
# \epsilon _h'(t) &= \frac{H \ u_x \ \epsilon_h(t)}{2 N \ \gamma_h(t)} \\
# \  \\
# \gamma _u'(t) &= -g h_x \\
# \xi _u'(t) &= u \\
# \epsilon _u'(t) &= \frac{g \ h_x \ \epsilon _u(t)}{2 \ \gamma_u(t)}
# \end{align}
#
# **Comentarios:**
# 1. Las partículas de altura y de velocidad se mueven de manera conjunta, manteniendo sus centros.

# %%
def F(X, t):
    #unpacking parameters
    Gamma_h = X[0:N] 
    Xi_h = X[N:2*N]
    Eps_h = X[2*N:3*N]
    Gamma_u = X[3*N:4*N]
    Xi_u = X[4*N:5*N]
    Eps_u = X[5*N:6*N]
    
    #computing derivatives at time t (autonomous system)
    f1 = -(H/N + Gamma_h) * ux(Xi_h, Gamma_u, Xi_u, Eps_u)
    f2 = u(Xi_h, Gamma_u, Xi_u, Eps_u)
    f3 = np.divide(H*ux(Xi_h, Gamma_u, Xi_u, Eps_u)*Eps_h, 2.*N*Gamma_h)
    f4 = -g*hx(Xi_u, Gamma_h, Xi_h, Eps_h)
    f5 = u(Xi_u, Gamma_u, Xi_u, Eps_u)
    f6 = np.divide(g*hx(Xi_u, Gamma_h, Xi_h, Eps_h)*Eps_u, 2.*Gamma_u)
    
    #returning values as flattened array
    return np.array([f1,f2,f3,f4,f5,f6]).ravel()

# %%
def euler(F,X0,dt,T):
    y = X0.copy()
    for t in T:
        sol = y[0:Nh], y[Nh:2*Nh], y[2*Nh:3*Nh], y[3*Nu:4*Nu], y[4*Nu:5*Nu], y[5*Nu:6*Nu]
        plt.plot(x, h(x,sol[0],sol[1],sol[2]))
        plt.xlabel('x')
        plt.ylabel('hx0')
        plt.title('Interpolated hx0')
        plt.show()
        y += F(t,X0)*dt

# %%
#initial conditions vector
X0 = np.array([Gamma_h, Xi_h, Eps_h, Gamma_u, Xi_u, Eps_u]).ravel()
y = X0.copy()
sol = y[0:Nh], y[Nh:2*Nh], y[2*Nh:3*Nh], y[3*Nu:4*Nu], y[4*Nu:5*Nu], y[5*Nu:6*Nu]
plt.plot(x, h(x,sol[0],sol[1],sol[2]))
plt.xlabel('x')
plt.ylabel('hx0')
plt.title('Interpolated hx0')
plt.show()

#times at w
t_start = 0.
t_end = 5.
t_step = 0.01
t_interval = np.arange(t_start, t_end, t_step)

#euler(F,X0,t_step,t_interval)

# %% [markdown]
# ## ODEINT

# %%
#initial conditions vector
X0 = np.array([Gamma_h, Xi_h, Eps_h, Gamma_u, Xi_u, Eps_u]).ravel()

#times at w
t_start = 0.
t_end = .5
t_step = 0.001
t_interval = np.arange(t_start, t_end, t_step)

#solve it!
sol = spi.odeint(F, X0, t_interval, mxstep=100000)
# Out:
# /home/martin/anaconda2/envs/python3/lib/python3.5/site-packages/ipykernel/__main__.py:16: RuntimeWarning: overflow encountered in true_divide
# /home/martin/anaconda2/envs/python3/lib/python3.5/site-packages/ipykernel/__main__.py:8: RuntimeWarning: invalid value encountered in multiply
# /home/martin/anaconda2/envs/python3/lib/python3.5/site-packages/ipykernel/__main__.py:5: RuntimeWarning: invalid value encountered in multiply
# /home/martin/anaconda2/envs/python3/lib/python3.5/site-packages/scipy/integrate/odepack.py:156: ODEintWarning: Illegal input detected (internal error). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %% [markdown]
# # ODE

# %%
func = lambda t,X : F(X,t)
ode =  spi.ode(func)
ode.set_integrator('vode',nsteps=1000,method='bdf')
ode.set_initial_value(X0,t_start)

# %%
while ode.successful() and ode.t < t_end:
    ode.integrate(ode.t + t_step)
    s = ode.y
    #Gamma_h
    print('min gamma_h', np.min(np.abs(s[0:N])))
    #Xi_h
    #s[N:2*N]
    #Eps_h
    #s[2*N:3*N]
    #Gamma_u
    print('min gamma_u', np.min(np.abs(s[3*N:4*N])))
    #Xi_u
    #s[4*N:5*N]
    #Eps_u
    #s[5*N:6*N]
    print('--------------------')
# Out:
# min gamma_h 0.00347570442226
# min gamma_u 0.00673963298824
# --------------------
# min gamma_h 0.00347570441074
# min gamma_u 0.00668367465845
# --------------------
# min gamma_h 0.00347570439801
# min gamma_u 0.00662714090482
# --------------------
# min gamma_h 0.00347570438406
# min gamma_u 0.00657001774197
# --------------------
# min gamma_h 0.0034757043689
# min gamma_u 0.00651229030915
# --------------------
# min gamma_h 0.00347570435251
# min gamma_u 0.00645394321672
# --------------------
# min gamma_h 0.0034757043349
# min gamma_u 0.00639496126556
# --------------------
# min gamma_h 0.00347570431606
# min gamma_u 0.00633532947642
# --------------------
# min gamma_h 0.00347570429599
# min gamma_u 0.00627503297234
# --------------------
# min gamma_h 0.00347570427468
# min gamma_u 0.00621405693962
# --------------------
# min gamma_h 0.00347570425214
# min gamma_u 0.00615238660976
# --------------------
# min gamma_h 0.00347570422836
# min gamma_u 0.00609000726674
# --------------------
# min gamma_h 0.00347570420335
# min gamma_u 0.00602690425758
# --------------------
# min gamma_h 0.0034757041771
# min gamma_u 0.00596306300166
# --------------------
# min gamma_h 0.00347570414962
# min gamma_u 0.00589846899068
# --------------------
# min gamma_h 0.00347570412092
# min gamma_u 0.005833107821
# --------------------
# min gamma_h 0.00347570409098
# min gamma_u 0.00576696518409
# --------------------
# min gamma_h 0.00347570405981
# min gamma_u 0.00570002687777
# --------------------
# min gamma_h 0.00347570402742
# min gamma_u 0.00563227881927
# --------------------
# min gamma_h 0.00347570399382
# min gamma_u 0.00556370706162
# --------------------
# min gamma_h 0.003475703959
# min gamma_u 0.00532093552777
# --------------------
# min gamma_h 0.00347570392297
# min gamma_u 0.00363351783957
# --------------------
# min gamma_h 0.00347570388573
# min gamma_u 0.00192842963129
# --------------------
# min gamma_h 0.00347570384729
# min gamma_u 0.000220119967947
# --------------------
# min gamma_h 0.00347570384224
# min gamma_u 5.81841881356e-33
# --------------------
# /home/martin/anaconda2/envs/python3/lib/python3.5/site-packages/scipy/integrate/_ode.py:852: UserWarning: vode: Excess work done on this call. (Perhaps wrong MF.)
#   'Unexpected istate=%s' % istate))

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(a,b), ylim=(5, 15))
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    X = sol[i]
    #unpacking
    Gamma_h = X[0:Nh] 
    Xi_h = X[Nh:2*Nh]
    Eps_h = X[2*Nh:3*Nh]
    Gamma_u = X[3*Nu:4*Nu]
    Xi_u = X[4*Nu:5*Nu]
    Eps_u = X[5*Nu:6*Nu]
    y = h(x, Gamma_h, Xi_h, Eps_h)
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=False)

# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is used, so that
# the video can be embedded in html5.  You may need to adjust this for
# your system: for more information, see
# http://matplotlib.sourceforge.net/api/animation_api.html
#anim.save('basic_animation.mp4', fps=30, extra_args=['-vcodec', 'libx264'])
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
for i in range(int(t_end/t_step)):
    if i%10!=0: continue
    X = sol[i]
    #unpacking
    Gamma_h = X[0:N] 
    Xi_h = X[N:2*N]
    Eps_h = X[2*N:3*N]
    Gamma_u = X[3*N:4*N]
    Xi_u = X[4*N:5*N]
    Eps_u = X[5*N:6*N]
    
    #plotting
    x = np.linspace(a, b, 1000)
    plt.plot(x, h(x, Gamma_h, Xi_h, Eps_h))
    plt.xlabel('x')
    plt.ylabel('h')
    plt.title('h solution')
    plt.show()

# %%
s = sol[26]
Gamma_h = s[0:N] 
Xi_h = s[N:2*N]
Eps_h = s[2*N:3*N]
Gamma_u = s[3*N:4*N]
Xi_u = s[4*N:5*N]
Eps_u = s[5*N:6*N]
x = np.linspace(a, b, 1000)
plt.plot(x, h(x, Gamma_h, Xi_h, Eps_h))
plt.xlabel('x')
plt.ylabel('h')
plt.title('h solution')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
